# %%
import pandas as pd
df = pd.read_csv('SmartTour_survey_2.csv')
df
# df.shape #size of dataset (row, col)
# df.describe() #basic details of the columns
# df.values #presents dataset in array form
# Out:
#     Gender     Age_Group               Attraction_Visited  Days_Spent  \
# 0     Male         36-45                    Beach Resorts           2
# 1   Female  less than 18        Lekki Conservative Center           1
# 2     Male         26-35                       Restaurant           5
# 3   Female         18-25                        Mapo hall           1
# 4   Female  less than 18               Obudu cattle ranch           3
# 5   Female         26-35                             None           3
# 6   Female         26-35                    Marina resort           3
# 7   Female         26-35                 Rest house,Ososo           1
# 8   Female         26-35                   Elegushi Beach           5
# 9     Male         26-35                       Olumo rock           1
# 10    Male         18-25                  Millennium park           3
# 11  Female         18-25                    National park           1
# ...
